# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""https://adventofcode.com/2024/day/10"""

from aoc_utils import fetch_input_data
import logging
logging.basicConfig(level=logging.INFO)
# logging.basicConfig(level=logging.DEBUG)
from itertools import product
import copy
import math

logger = logging.getLogger(__name__)
actual_input = fetch_input_data(2024, 10)
sample_input = """\
89010123
78121874
87430965
96549874
45678903
32019012
01329801
10456732\
"""

# %%
from day10 import convert_to_grid, grid_to_str, find_trailheads, search_neighbors_for

# %%
sample_grid = convert_to_grid(sample_input, astype='str')
trailheads = find_trailheads(sample_grid, target='0')

# %%
sample_grid
# Out:
# [['8', '9', '0', '1', '0', '1', '2', '3'],
#  ['7', '8', '1', '2', '1', '8', '7', '4'],
#  ['8', '7', '4', '3', '0', '9', '6', '5'],
#  ['9', '6', '5', '4', '9', '8', '7', '4'],
#  ['4', '5', '6', '7', '8', '9', '0', '3'],
#  ['3', '2', '0', '1', '9', '0', '1', '2'],
#  ['0', '1', '3', '2', '9', '8', '0', '1'],
#  ['1', '0', '4', '5', '6', '7', '3', '2']]

# %%
trailheads
# Out:
# [(2, 0), (4, 0), (4, 2), (6, 4), (2, 5), (5, 5), (0, 6), (6, 6), (1, 7)]

# %%
search_neighbors_for(grid=sample_grid,pos=(6, 4),target='1')
# Out:
# [(6, 5)]

# %%
def parse_input(input_str):
    return [[int(c) for c in line.strip()] for line in input_str.strip().split('\n')]

def get_neighbors(x, y, rows, cols):
    directions = [
        (0, 1), # right
        (1, 0), # down
        (0, -1), # left
        (-1, 0), # up
    ] 
    neighbors = []
    for dx, dy in directions:
        new_x, new_y = x + dx, y + dy
        if 0 <= new_x < rows and 0 <= new_y < cols:
            neighbors.append((new_x, new_y))
    return neighbors

def find_hiking_trails(grid, start_x, start_y):
    if grid[start_x][start_y] != 0:
        return 0
    
    rows, cols = len(grid), len(grid[0])
    reachable_nines = set()
    
    def dfs(x, y, visited):
        if grid[x][y] == 9:
            reachable_nines.add((x, y))
            return
        
        current_height = grid[x][y]
        for nx, ny in get_neighbors(x, y, rows, cols):
            if (nx, ny) not in visited and grid[nx][ny] == current_height + 1:
                visited.add((nx, ny))
                dfs(nx, ny, visited)
                visited.remove((nx, ny))
    
    dfs(start_x, start_y, {(start_x, start_y)})
    return len(reachable_nines)

def solve(input_str):
    grid = parse_input(input_str)
    rows, cols = len(grid), len(grid[0])
    total_score = 0
    
    # Find all trailheads (positions with height 0)
    for i in range(rows):
        for j in range(cols):
            if grid[i][j] == 0:
                score = find_hiking_trails(grid, i, j)
                total_score += score
    
    return total_score

# Test with example
test_input = """89010123
78121874
87430965
96549874
45678903
32019012
01329801
10456732"""

result = solve(test_input)
print(f"Test result: {result}")  # Should print 36
# Out:
# Test result: 36

# %%
result = solve(actual_input)

# %%
def parse_input(input_str):
    return [[int(c) for c in line.strip()] for line in input_str.strip().split('\n')]

def get_neighbors(x, y, rows, cols):
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
    neighbors = []
    for dx, dy in directions:
        new_x, new_y = x + dx, y + dy
        if 0 <= new_x < rows and 0 <= new_y < cols:
            neighbors.append((new_x, new_y))
    return neighbors

def count_unique_trails(grid, start_x, start_y):
    if grid[start_x][start_y] != 0:
        return 0
    
    rows, cols = len(grid), len(grid[0])
    trail_count = 0
    
    def dfs(x, y, visited):
        nonlocal trail_count
        if grid[x][y] == 9:
            # Found a complete trail
            trail_count += 1
            return
        
        current_height = grid[x][y]
        for nx, ny in get_neighbors(x, y, rows, cols):
            if (nx, ny) not in visited and grid[nx][ny] == current_height + 1:
                visited.add((nx, ny))
                dfs(nx, ny, visited)
                visited.remove((nx, ny))
    
    dfs(start_x, start_y, {(start_x, start_y)})
    return trail_count

def solve_part_2(input_str):
    grid = parse_input(input_str)
    rows, cols = len(grid), len(grid[0])
    total_rating = 0
    
    # Find all trailheads (positions with height 0)
    for i in range(rows):
        for j in range(cols):
            if grid[i][j] == 0:
                rating = count_unique_trails(grid, i, j)
                total_rating += rating
                print(f"Trailhead at ({i}, {j}) has rating: {rating}")
    
    return total_rating

# Test with examples
test_inputs = [
    # Example 1 - rating 3
    """.....0.
..4321.
..5..2.
..6543.
..7..4.
..8765.
..9....""",

    # Example 2 - rating 13
    """..90..9
...1.98
...2..7
6543456
765.987
876....
987....""",

    # Example 3 - rating 227
    """012345
123456
234567
345678
4.6789
56789.""",

    # Larger example - sum of ratings 81
    """89010123
78121874
87430965
96549874
45678903
32019012
01329801
10456732"""
]

for i, test in enumerate(test_inputs, 1):
    print(f"\nTesting example {i}:")
    result = solve_part_2(test)
    print(f"Result: {result}")
# Out:
# Testing example 1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 93
#      91 for i, test in enumerate(test_inputs, 1):
#      92     print(f"\nTesting example {i}:")
# ---> 93     result = solve_part_2(test)
#      94     print(f"Result: {result}")
#
# Cell In[61], line 38, in solve_part_2(input_str)
#      37 def solve_part_2(input_str):
# ---> 38     grid = parse_input(input_str)
#      39     rows, cols = len(grid), len(grid[0])
#      40     total_rating = 0
#
# Cell In[61], line 2, in parse_input(input_str)
#       1 def parse_input(input_str):
# ----> 2     return [[int(c) for c in line.strip()] for line in input_str.strip().split('\n')]
#
# Cell In[61], line 2, in <listcomp>(.0)
#       1 def parse_input(input_str):
# ----> 2     return [[int(c) for c in line.strip()] for line in input_str.strip().split('\n')]
#
# Cell In[61], line 2, in <listcomp>(.0)
#       1 def parse_input(input_str):
# ----> 2     return [[int(c) for c in line.strip()] for line in input_str.strip().split('\n')]
#
# ValueError: invalid literal for int() with base 10: '.'

# %%
solve_part_2(actual_input)
# Out:
# Trailhead at (0, 8) has rating: 4
# Trailhead at (0, 19) has rating: 8
# Trailhead at (0, 23) has rating: 1
# Trailhead at (0, 24) has rating: 4
# Trailhead at (0, 26) has rating: 2
# Trailhead at (0, 38) has rating: 2
# Trailhead at (0, 47) has rating: 10
# Trailhead at (0, 51) has rating: 1
# Trailhead at (0, 58) has rating: 3
# Trailhead at (1, 0) has rating: 2
# Trailhead at (2, 11) has rating: 8
# Trailhead at (2, 26) has rating: 6
# Trailhead at (2, 32) has rating: 6
# Trailhead at (2, 37) has rating: 13
# Trailhead at (2, 47) has rating: 9
# Trailhead at (3, 3) has rating: 9
# Trailhead at (3, 16) has rating: 4
# Trailhead at (3, 33) has rating: 7
# Trailhead at (3, 50) has rating: 7
# Trailhead at (3, 58) has rating: 1
# Trailhead at (4, 1) has rating: 2
# Trailhead at (4, 14) has rating: 3
# Trailhead at (4, 21) has rating: 2
# Trailhead at (4, 39) has rating: 13
# Trailhead at (4, 53) has rating: 7
# Trailhead at (5, 3) has rating: 4
# Trailhead at (5, 13) has rating: 3
# Trailhead at (5, 14) has rating: 5
# Trailhead at (5, 27) has rating: 1
# Trailhead at (5, 31) has rating: 2
# Trailhead at (5, 37) has rating: 7
# Trailhead at (6, 4) has rating: 2
# Trailhead at (6, 17) has rating: 9
# Trailhead at (6, 22) has rating: 5
# Trailhead at (6, 41) has rating: 13
# Trailhead at (6, 44) has rating: 1
# Trailhead at (6, 48) has rating: 3
# Trailhead at (7, 1) has rating: 1
# Trailhead at (7, 7) has rating: 8
# Trailhead at (7, 10) has rating: 10
# Trailhead at (7, 28) has rating: 4
# Trailhead at (7, 35) has rating: 4
# Trailhead at (7, 54) has rating: 4
# Trailhead at (8, 6) has rating: 8
# Trailhead at (8, 7) has rating: 10
# Trailhead at (8, 20) has rating: 5
# Trailhead at (8, 26) has rating: 5
# Trailhead at (8, 30) has rating: 4
# Trailhead at (8, 44) has rating: 18
# Trailhead at (9, 35) has rating: 1
# Trailhead at (9, 43) has rating: 7
# Trailhead at (9, 53) has rating: 6
# Trailhead at (10, 14) has rating: 5
# Trailhead at (10, 39) has rating: 2
# Trailhead at (10, 51) has rating: 7
# Trailhead at (10, 54) has rating: 12
# Trailhead at (11, 8) has rating: 13
# Trailhead at (11, 41) has rating: 3
# Trailhead at (11, 57) has rating: 5
# Trailhead at (12, 0) has rating: 7
# Trailhead at (12, 20) has rating: 1
# Trailhead at (12, 47) has rating: 18
# Trailhead at (13, 6) has rating: 1
# Trailhead at (13, 8) has rating: 3
# Trailhead at (13, 17) has rating: 6
# Trailhead at (13, 18) has rating: 7
# Trailhead at (13, 27) has rating: 3
# Trailhead at (13, 30) has rating: 8
# Trailhead at (13, 32) has rating: 4
# Trailhead at (13, 36) has rating: 6
# Trailhead at (13, 41) has rating: 3
# Trailhead at (13, 50) has rating: 4
# Trailhead at (13, 55) has rating: 3
# Trailhead at (14, 0) has rating: 21
# Trailhead at (14, 26) has rating: 2
# Trailhead at (14, 35) has rating: 3
# Trailhead at (14, 36) has rating: 12
# Trailhead at (14, 42) has rating: 2
# Trailhead at (14, 47) has rating: 6
# Trailhead at (14, 50) has rating: 2
# Trailhead at (15, 0) has rating: 1
# Trailhead at (15, 9) has rating: 2
# Trailhead at (15, 11) has rating: 8
# Trailhead at (15, 22) has rating: 3
# Trailhead at (15, 37) has rating: 20
# Trailhead at (15, 52) has rating: 4
# Trailhead at (16, 1) has rating: 7
# Trailhead at (16, 10) has rating: 6
# Trailhead at (16, 39) has rating: 1
# Trailhead at (16, 55) has rating: 2
# Trailhead at (17, 0) has rating: 15
# Trailhead at (17, 10) has rating: 1
# Trailhead at (17, 18) has rating: 5
# Trailhead at (17, 28) has rating: 1
# Trailhead at (17, 37) has rating: 8
# Trailhead at (17, 47) has rating: 4
# Trailhead at (18, 3) has rating: 3
# Trailhead at (18, 6) has rating: 2
# Trailhead at (18, 19) has rating: 4
# Trailhead at (18, 22) has rating: 2
# Trailhead at (18, 41) has rating: 4
# Trailhead at (18, 43) has rating: 4
# Trailhead at (18, 46) has rating: 1
# Trailhead at (19, 11) has rating: 8
# Trailhead at (19, 18) has rating: 4
# Trailhead at (19, 23) has rating: 6
# Trailhead at (19, 30) has rating: 1
# Trailhead at (19, 51) has rating: 7
# Trailhead at (19, 55) has rating: 3
# Trailhead at (19, 58) has rating: 3
# Trailhead at (20, 14) has rating: 3
# Trailhead at (20, 24) has rating: 4
# Trailhead at (20, 33) has rating: 2
# Trailhead at (20, 39) has rating: 3
# Trailhead at (20, 47) has rating: 5
# Trailhead at (20, 50) has rating: 4
# Trailhead at (21, 6) has rating: 3
# Trailhead at (21, 8) has rating: 8
# Trailhead at (21, 9) has rating: 1
# Trailhead at (21, 21) has rating: 16
# Trailhead at (21, 53) has rating: 1
# Trailhead at (22, 18) has rating: 7
# Trailhead at (22, 26) has rating: 4
# Trailhead at (22, 39) has rating: 6
# Trailhead at (22, 58) has rating: 2
# Trailhead at (23, 7) has rating: 1
# Trailhead at (23, 25) has rating: 4
# Trailhead at (23, 37) has rating: 2
# Trailhead at (24, 2) has rating: 6
# Trailhead at (24, 11) has rating: 2
# Trailhead at (24, 22) has rating: 21
# Trailhead at (24, 29) has rating: 4
# Trailhead at (24, 38) has rating: 10
# Trailhead at (24, 47) has rating: 8
# Trailhead at (24, 55) has rating: 2
# Trailhead at (25, 5) has rating: 14
# Trailhead at (25, 15) has rating: 4
# Trailhead at (25, 18) has rating: 1
# Trailhead at (25, 32) has rating: 5
# Trailhead at (25, 45) has rating: 2
# Trailhead at (25, 50) has rating: 7
# Trailhead at (25, 54) has rating: 2
# Trailhead at (26, 14) has rating: 4
# Trailhead at (26, 24) has rating: 3
# Trailhead at (26, 28) has rating: 3
# Trailhead at (26, 40) has rating: 6
# Trailhead at (26, 49) has rating: 7
# Trailhead at (26, 56) has rating: 4
# Trailhead at (27, 12) has rating: 1
# Trailhead at (27, 52) has rating: 7
# Trailhead at (28, 2) has rating: 3
# Trailhead at (28, 7) has rating: 1
# Trailhead at (28, 10) has rating: 2
# Trailhead at (28, 33) has rating: 8
# Trailhead at (28, 35) has rating: 2
# Trailhead at (28, 43) has rating: 5
# Trailhead at (28, 47) has rating: 1
# Trailhead at (28, 57) has rating: 2
# Trailhead at (29, 17) has rating: 2
# Trailhead at (29, 27) has rating: 4
# Trailhead at (29, 38) has rating: 2
# Trailhead at (29, 57) has rating: 9
# Trailhead at (30, 0) has rating: 1
# Trailhead at (30, 15) has rating: 2
# Trailhead at (30, 19) has rating: 2
# Trailhead at (30, 23) has rating: 3
# Trailhead at (30, 26) has rating: 6
# Trailhead at (30, 41) has rating: 3
# Trailhead at (30, 58) has rating: 12
# Trailhead at (31, 2) has rating: 2
# Trailhead at (31, 12) has rating: 2
# Trailhead at (31, 25) has rating: 2
# Trailhead at (31, 33) has rating: 5
# Trailhead at (31, 40) has rating: 3
# Trailhead at (31, 42) has rating: 1
# Trailhead at (31, 49) has rating: 1
# Trailhead at (32, 10) has rating: 10
# Trailhead at (32, 15) has rating: 4
# Trailhead at (32, 24) has rating: 1
# Trailhead at (32, 45) has rating: 22
# Trailhead at (32, 54) has rating: 8
# Trailhead at (33, 8) has rating: 1
# Trailhead at (33, 34) has rating: 1
# Trailhead at (33, 37) has rating: 3
# Trailhead at (33, 46) has rating: 18
# Trailhead at (33, 48) has rating: 4
# Trailhead at (34, 48) has rating: 1
# Trailhead at (35, 3) has rating: 1
# Trailhead at (35, 5) has rating: 2
# Trailhead at (35, 23) has rating: 3
# Trailhead at (35, 29) has rating: 5
# Trailhead at (35, 33) has rating: 6
# Trailhead at (35, 42) has rating: 5
# Trailhead at (36, 21) has rating: 2
# Trailhead at (36, 26) has rating: 3
# Trailhead at (36, 36) has rating: 2
# Trailhead at (36, 52) has rating: 2
# Trailhead at (37, 3) has rating: 5
# Trailhead at (37, 7) has rating: 12
# Trailhead at (37, 10) has rating: 1
# Trailhead at (37, 11) has rating: 1
# Trailhead at (37, 18) has rating: 4
# Trailhead at (37, 23) has rating: 3
# Trailhead at (37, 32) has rating: 3
# Trailhead at (37, 41) has rating: 2
# Trailhead at (37, 46) has rating: 4
# Trailhead at (37, 50) has rating: 3
# Trailhead at (37, 58) has rating: 2
# Trailhead at (38, 9) has rating: 2
# Trailhead at (38, 11) has rating: 2
# Trailhead at (38, 12) has rating: 2
# Trailhead at (38, 21) has rating: 1
# Trailhead at (38, 36) has rating: 5
# Trailhead at (38, 45) has rating: 7
# Trailhead at (38, 49) has rating: 3
# Trailhead at (38, 58) has rating: 2
# Trailhead at (39, 16) has rating: 1
# Trailhead at (39, 20) has rating: 2
# Trailhead at (39, 23) has rating: 2
# Trailhead at (39, 54) has rating: 2
# Trailhead at (40, 24) has rating: 2
# Trailhead at (40, 29) has rating: 2
# Trailhead at (40, 37) has rating: 1
# Trailhead at (40, 58) has rating: 1
# Trailhead at (41, 1) has rating: 4
# Trailhead at (41, 3) has rating: 2
# Trailhead at (41, 5) has rating: 6
# Trailhead at (41, 12) has rating: 3
# Trailhead at (41, 23) has rating: 2
# Trailhead at (41, 29) has rating: 5
# Trailhead at (41, 32) has rating: 5
# Trailhead at (41, 57) has rating: 4
# Trailhead at (42, 10) has rating: 5
# Trailhead at (42, 19) has rating: 2
# Trailhead at (42, 30) has rating: 5
# Trailhead at (42, 34) has rating: 1
# Trailhead at (42, 42) has rating: 1
# Trailhead at (42, 44) has rating: 6
# Trailhead at (43, 17) has rating: 5
# Trailhead at (43, 22) has rating: 4
# Trailhead at (43, 36) has rating: 2
# Trailhead at (43, 39) has rating: 1
# Trailhead at (43, 51) has rating: 14
# Trailhead at (44, 26) has rating: 3
# Trailhead at (44, 37) has rating: 2
# Trailhead at (44, 45) has rating: 2
# Trailhead at (44, 52) has rating: 15
# Trailhead at (44, 55) has rating: 1
# Trailhead at (45, 3) has rating: 2
# Trailhead at (45, 13) has rating: 3
# Trailhead at (45, 17) has rating: 3
# Trailhead at (45, 33) has rating: 8
# Trailhead at (45, 34) has rating: 2
# Trailhead at (45, 35) has rating: 1
# Trailhead at (45, 43) has rating: 2
# Trailhead at (46, 1) has rating: 1
# Trailhead at (46, 2) has rating: 2
# Trailhead at (46, 15) has rating: 2
# Trailhead at (46, 23) has rating: 6
# Trailhead at (46, 43) has rating: 4
# Trailhead at (46, 52) has rating: 1
# Trailhead at (47, 7) has rating: 2
# Trailhead at (47, 10) has rating: 4
# Trailhead at (47, 28) has rating: 2
# Trailhead at (47, 50) has rating: 7
# Trailhead at (48, 10) has rating: 1
# Trailhead at (48, 20) has rating: 2
# Trailhead at (48, 37) has rating: 2
# Trailhead at (48, 39) has rating: 9
# Trailhead at (48, 44) has rating: 4
# Trailhead at (48, 46) has rating: 8
# Trailhead at (48, 53) has rating: 2
# Trailhead at (49, 1) has rating: 6
# Trailhead at (49, 17) has rating: 2
# Trailhead at (49, 18) has rating: 3
# Trailhead at (49, 33) has rating: 1
# Trailhead at (49, 40) has rating: 9
# Trailhead at (49, 57) has rating: 2
# Trailhead at (50, 25) has rating: 10
# Trailhead at (50, 33) has rating: 2
# Trailhead at (50, 38) has rating: 1
# Trailhead at (50, 46) has rating: 9
# Trailhead at (51, 27) has rating: 2
# Trailhead at (51, 36) has rating: 4
# Trailhead at (51, 53) has rating: 8
# Trailhead at (52, 14) has rating: 7
# Trailhead at (52, 22) has rating: 1
# Trailhead at (52, 32) has rating: 1
# Trailhead at (52, 42) has rating: 3
# Trailhead at (52, 43) has rating: 4
# Trailhead at (53, 5) has rating: 5
# Trailhead at (53, 15) has rating: 2
# Trailhead at (53, 50) has rating: 7
# Trailhead at (53, 54) has rating: 1
# Trailhead at (54, 0) has rating: 3
# Trailhead at (54, 21) has rating: 12
# Trailhead at (54, 56) has rating: 1
# Trailhead at (55, 5) has rating: 5
# Trailhead at (55, 9) has rating: 3
# Trailhead at (55, 14) has rating: 4
# Trailhead at (55, 21) has rating: 2
# Trailhead at (55, 27) has rating: 4
# Trailhead at (55, 40) has rating: 2
# Trailhead at (55, 53) has rating: 1
# Trailhead at (56, 3) has rating: 2
# Trailhead at (56, 14) has rating: 16
# Trailhead at (56, 24) has rating: 2
# Trailhead at (56, 25) has rating: 1
# Trailhead at (56, 29) has rating: 4
# Trailhead at (56, 56) has rating: 3
# Trailhead at (57, 8) has rating: 2
# Trailhead at (57, 13) has rating: 32
# Trailhead at (57, 21) has rating: 1
# Trailhead at (57, 23) has rating: 1
# Trailhead at (57, 28) has rating: 2
# Trailhead at (57, 34) has rating: 5
# Trailhead at (57, 39) has rating: 1
# Trailhead at (57, 47) has rating: 4
# Trailhead at (58, 5) has rating: 6
# Trailhead at (58, 7) has rating: 8
# Trailhead at (58, 33) has rating: 2
# Trailhead at (58, 41) has rating: 1
# 1459
